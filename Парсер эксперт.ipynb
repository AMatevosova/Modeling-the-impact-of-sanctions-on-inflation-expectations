# %%
import requests
import pandas as pd
import time
import warnings
warnings.filterwarnings('ignore')

# %%
token="здесь должен быть токен"

# %%
group_name="expert_news"
offset=0
count=100
all_posts=[]
all_comments=[]

# %%
while offset<1000:
    req=requests.get('https://api.vk.com/method/wall.search',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'domain': group_name,
                   'query': 'цен',
                   'count': count,
                   'offset': offset
                   
               })
    res=req.json()['response']['items']
    offset+=100
    all_posts.extend(res)

# %%
df = pd.json_normalize(all_posts)
df
# Out:
#          id    from_id  owner_id        date  marked_as_ads  short_text_rate  \
# 0    261150  -26517977 -26517977  1674467771              0              0.8
# 1    261148  -26517977 -26517977  1674461038              0              0.8
# 2    261130  -26517977 -26517977  1674392521              0              0.8
# 3    261117  -26517977 -26517977  1674298920              0              0.8
# 4    261002  154369535 -26517977  1674199454              0              0.8
# ..      ...        ...       ...         ...            ...              ...
# 995  243415  -26517977 -26517977  1625232000              0              0.8
# 996  243316  230576110 -26517977  1624646346              0              0.8
# 997  243312  -26517977 -26517977  1624618123              0              0.8
# 998  243247  -26517977 -26517977  1624444160              0              0.8
# 999  243173    3341135 -26517977  1624371197              0              0.8
#
#                                            attachments  is_favorite post_type  \
# 0    [{'type': 'link', 'link': {'url': 'https://exp...        False      post
# 1    [{'type': 'link', 'link': {'url': 'https://exp...        False      post
# 2    [{'type': 'link', 'link': {'url': 'https://exp...        False      post
# 3    [{'type': 'link', 'link': {'url': 'https://exp...        False      post
# 4                                                   []        False     reply
# ..                                                 ...          ...       ...
# 995  [{'type': 'photo', 'photo': {'album_id': -7, '...        False      post
# 996                                                 []        False     reply
# 997  [{'type': 'photo', 'photo': {'album_id': -7, '...        False      post
# 998  [{'type': 'photo', 'photo': {'album_id': -7, '...        False      post
# 999                                                 []        False     reply
#
#                                                   text  ...  \
# 0    Ценовой потолок на нефть оказался малоэффектив...  ...
# 1    В США напомнили о крахе сланцевиков и призвали...  ...
# 2    Дефицит ликвидности по-прежнему затрудняет опр...  ...
# 3    В России из-за резкого сокращения поставок кра...  ...
# 4    Детки решили жить самостоятельно (😆)...\nА на ...  ...
# ..                                                 ...  ...
# 995  На российском авторынке беспрецедентный дефици...  ...
# 996  ниче пускай барыги "провалятся" им полезно буд...  ...
# 997  Экспорт газа из России в континентальную Европ...  ...
# 998  Волатильность наделала проблем. IPO компании N...  ...
# 999  Наши курорты - это хамство, отвратительный сер...  ...
#
#     post_source.platform  post_source.type  reposts.count  \
# 0                 iphone               api              2
# 1                    NaN                vk              1
# 2                    NaN                vk              1
# 3                    NaN                vk             10
# 4                    NaN                vk              0
# ..                   ...               ...            ...
# 995                  NaN                vk              1
# 996                  NaN                vk              0
# 997                  NaN                vk              1
# 998                  NaN                vk              1
# 999                  NaN                vk              0
#
#      reposts.user_reposted  views.count   post_id  parents_stack  zoom_text  \
# 0                        0        336.0       NaN            NaN        NaN
# 1                        0        465.0       NaN            NaN        NaN
# 2                        0        858.0       NaN            NaN        NaN
# 3                        0       2062.0       NaN            NaN        NaN
# 4                        0          NaN  261002.0             []        NaN
# ..                     ...          ...       ...            ...        ...
# 995                      0       1981.0       NaN            NaN        NaN
# 996                      0          NaN  243316.0             []        NaN
# 997                      0       1214.0       NaN            NaN        NaN
# 998                      0        657.0       NaN            NaN        NaN
# 999                      0          NaN  243173.0             []       True
#
#     carousel_offset edited
# 0               NaN    NaN
# 1               NaN    NaN
# 2               NaN    NaN
# 3               NaN    NaN
# 4               NaN    NaN
# ..              ...    ...
# 995             NaN    NaN
# 996             NaN    NaN
# 997             NaN    NaN
# 998             NaN    NaN
# 999             NaN    NaN
#
# [1000 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1000 non-null   int64
#  1   from_id                1000 non-null   int64
#  2   owner_id               1000 non-null   int64
#  3   date                   1000 non-null   int64
#  4   marked_as_ads          1000 non-null   int64
#  5   short_text_rate        1000 non-null   float64
#  6   attachments            1000 non-null   object
#  7   is_favorite            1000 non-null   bool
#  8   post_type              1000 non-null   object
#  9   text                   1000 non-null   object
#  10  hash                   1000 non-null   object
#  11  donut.is_donut         1000 non-null   bool
#  12  comments.can_post      1000 non-null   int64
#  13  comments.count         1000 non-null   int64
#  14  likes.can_like         1000 non-null   int64
#  15  likes.count            1000 non-null   int64
#  16  likes.user_likes       1000 non-null   int64
#  17  likes.can_publish      1000 non-null   int64
#  18  post_source.platform   649 non-null    object
#  19  post_source.type       1000 non-null   object
#  20  reposts.count          1000 non-null   int64
#  21  reposts.user_reposted  1000 non-null   int64
#  22  views.count            737 non-null    float64
#  23  post_id                263 non-null    float64
#  24  parents_stack          263 non-null    object
#  25  zoom_text              75 non-null     object
#  26  carousel_offset        19 non-null     float64
#  27  edited                 50 non-null     float64
# dtypes: bool(2), float64(5), int64(13), object(8)
# memory usage: 205.2+ KB

# %%
df=df[["id", "owner_id", "date", "text", "comments.count"]]
df.rename(columns={'date': 'post_time','text':'post_text'}, inplace=True)
df=df[df['post_time']>=1630454400]
df=df[df['comments.count']!=0]
df.set_index('id')
# Out:
#         owner_id   post_time  \
# id
# 261117 -26517977  1674298920
# 261089 -26517977  1674148800
# 260811 -26517977  1673107800
# 260735 -26517977  1672816200
# 260414 -26517977  1671802200
# ...          ...         ...
# 244962 -26517977  1630681500
# 244960 -26517977  1630677900
# 244919 -26517977  1630606576
# 244879 -26517977  1630494360
# 244870 -26517977  1630487100
#
#                                                 post_text  comments.count
# id
# 261117  В России из-за резкого сокращения поставок кра...               1
# 261089  В ЦБ объяснили, почему арендовать квартиру мож...               1
# 260811  Глава Минэнерго Турции заявил, что в стране от...               2
# 260735  Прогнозы по максимальной цене золота в 2023 го...               1
# 260414  Центральный банк Российской Федерации продлит ...               1
# ...                                                   ...             ...
# 244962  Правительство усиливает контроль за ростом цен...              14
# 244960  Российская сеть магазинов низких цен вышла на ...               2
# 244919  Акции дня: бумаги «Русала» торговались по летн...               1
# 244879  На каких принципах построить сбор и хранение ц...               5
# 244870  Одним из ключевых факторов, способствующих рос...               7
#
# [235 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 235 entries, 3 to 863
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              235 non-null    int64
#  1   owner_id        235 non-null    int64
#  2   post_time       235 non-null    int64
#  3   post_text       235 non-null    object
#  4   comments.count  235 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 11.0+ KB

# %%
owner_id=-26517977
posts_id=list(df['id'])

# %%
for post_id in posts_id:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)

# %%
data = pd.json_normalize(all_comments)
data
# Out:
#          id    from_id        date  \
# 0    261120  710313517  1674315737
# 1    261090     254867  1674149226
# 2    260812  710313517  1673107987
# 3    260813   12697056  1673109630
# 4    260737  710313517  1672817976
# ..      ...        ...         ...
# 659  244873  418165222  1630488189
# 660  244874  315402790  1630488801
# 661  244875  640119947  1630489632
# 662  244888    1693057  1630508529
# 663  244904  219523024  1630566369
#
#                                                   text   post_id    owner_id  \
# 0           Серьёзная тема для российского рыбоводства  261117.0 -26517977.0
# 1    а может и не быть... Через 30 лет аренда будет...  261089.0 -26517977.0
# 2    Интересно, они ещё и в своей валюте догадются ...  260811.0 -26517977.0
# 3             Запах  денег манит  и перевыборы скоро.)  260811.0 -26517977.0
# 4    Как минимум национальные биржи должны упростит...  260735.0 -26517977.0
# ..                                                 ...       ...         ...
# 659  Ведь почти во всех регионах цены в самом деле ...  244870.0 -26517977.0
# 660  Согласно статистике, в Алтае, Забайкалье, Калу...  244870.0 -26517977.0
# 661  Рост цен на продукты неизбежен, но Путин старе...  244870.0 -26517977.0
# 662         Национальное достояние уходит не в те руки  244870.0 -26517977.0
# 663  Надо было просто ещё в 10е года создавать госу...  244870.0 -26517977.0
#
#     parents_stack  thread.count thread.items  thread.can_post  \
# 0              []             0           []             True
# 1              []             0           []             True
# 2              []             0           []             True
# 3              []             0           []             True
# 4              []             0           []             True
# ..            ...           ...          ...              ...
# 659            []             0           []             True
# 660            []             0           []             True
# 661            []             0           []             True
# 662            []             0           []             True
# 663            []             0           []             True
#
#      thread.show_reply_button attachments deleted
# 0                        True         NaN     NaN
# 1                        True         NaN     NaN
# 2                        True         NaN     NaN
# 3                        True         NaN     NaN
# 4                        True         NaN     NaN
# ..                        ...         ...     ...
# 659                      True         NaN     NaN
# 660                      True         NaN     NaN
# 661                      True         NaN     NaN
# 662                      True         NaN     NaN
# 663                      True         NaN     NaN
#
# [664 rows x 13 columns]

# %%
data=data[["post_id", "text", "date"]]
data.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data=data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 661 entries, 0 to 663
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   post_id       661 non-null    float64
#  1   text          661 non-null    object
#  2   comment_time  661 non-null    int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 20.7+ KB

# %%
data['post_id'] = data['post_id'].astype(int)
data
# Out:
#      post_id                                               text  comment_time
# 0     261117         Серьёзная тема для российского рыбоводства    1674315737
# 1     261089  а может и не быть... Через 30 лет аренда будет...    1674149226
# 2     260811  Интересно, они ещё и в своей валюте догадются ...    1673107987
# 3     260811           Запах  денег манит  и перевыборы скоро.)    1673109630
# 4     260735  Как минимум национальные биржи должны упростит...    1672817976
# ..       ...                                                ...           ...
# 659   244870  Ведь почти во всех регионах цены в самом деле ...    1630488189
# 660   244870  Согласно статистике, в Алтае, Забайкалье, Калу...    1630488801
# 661   244870  Рост цен на продукты неизбежен, но Путин старе...    1630489632
# 662   244870         Национальное достояние уходит не в те руки    1630508529
# 663   244870  Надо было просто ещё в 10е года создавать госу...    1630566369
#
# [661 rows x 3 columns]

# %%
df.to_csv('expert_posts.csv', index=False)

# %%
data.to_csv('expert_comments.csv', index=False)
